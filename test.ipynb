# %%
import numpy as np
import matplotlib.pyplot as plt
from func import GuessPlayer
from tensorflow.keras.preprocessing import image
from tensorflow import keras
model = keras.models.load_model('FinalModel.h5')

# %% [markdown]
# ## Loading image which we want to check

# %%
img1 = image.load_img("which player 13.jpg"
                    ,target_size = (100,100))
plt.imshow(img1)
test_img = np.asarray(img1)
# reshape to add 1 row
test_img = test_img.reshape(1,100,100,3)
yhat = model.predict(test_img)
GuessPlayer(yhat)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# 'M. S. DHONI'
